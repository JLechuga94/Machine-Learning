# %% [markdown]
# # PCA with `scikit-learn`

# %% [markdown]
# # 1. First example

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn import decomposition
from sklearn.decomposition import PCA
from sklearn import datasets

# %%
X = np.random.randn(500,3)
print(X)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2])
plt.title("Simulated Data")
plt.show()
# Out:
# [[-0.35984639  3.45483469  0.53793255]
#  [ 1.20124621  0.51833541  1.78496108]
#  [-1.52256635 -0.33844052 -1.02526839]
#  ...
#  [-0.93251843  1.52199579  0.09289325]
#  [-0.58269176 -1.11680757  1.10125717]
#  [-1.36464643 -0.7464292   0.40329124]]

# %%
pca = PCA(n_components=3)
pca.fit(X)

print("% explained variance: ")
print(pca.explained_variance_ratio_)
print("Principal components: ")
print(pca.components_)
# Out:
# % explained variance:
# [0.52880301 0.42440593 0.04679106]
# Principal components:
# [[ 0.4100804   0.29468414  0.86313112]
#  [ 0.88825658  0.08571047 -0.45128037]
#  [-0.20696454  0.95174312 -0.22660694]]

# %%
x_pca = pca.transform(X)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1])
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
x_pca = pca.transform(X)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,2])
plt.xlabel('First principal component')
plt.ylabel('Third Principal Component')
# Out:
# Text(0, 0.5, 'Third Principal Component')

# %%
mean = (1, 2,-4)
cov = [[5, 1,0], [1, 1,1],[0,1,5]]
X = np.random.multivariate_normal(mean, cov, 1000)
print(X.shape)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2])
plt.title("Simulated Data")
plt.show()
# Out:
# (1000, 3)

# %%
scaler = StandardScaler()
scaler.fit(X)
scaled_data = scaler.transform(X)
print(X)
pca = PCA(n_components=3)
pca.fit(scaled_data)

print("% explained variance: ")
print(pca.explained_variance_ratio_)
print("Principal components: ")
print(pca.components_)
# Out:
# [[-0.33106916  3.51393682  0.50836593]
#  [ 1.17868318  0.52005222  1.73003204]
#  [-1.4555503  -0.3534669  -1.02304218]
#  ...
#  [-0.88490751  1.54332621  0.07237797]
#  [-0.54658573 -1.14704487  1.06023348]
#  [-1.30282395 -0.76942853  0.37646299]]
# % explained variance:
# [0.36891087 0.3306521  0.30043703]
# Principal components:
# [[ 0.50255572  0.516739    0.69312232]
#  [ 0.71859443 -0.69542465 -0.00256912]
#  [ 0.48068678  0.49936497 -0.7208154 ]]

# %%
x_pca = pca.transform(scaled_data)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1])
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,2])
plt.xlabel('First principal component')
plt.ylabel('Third Principal Component')
# Out:
# Text(0, 0.5, 'Third Principal Component')

# %% [markdown]
# # 2. Iris Data Set

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

for name, label in [('Setosa', 0), ('Versicolor', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))

ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap='rainbow', edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# # 3. Study of an economic data set

# %% [markdown]
# Study the Data Set "Régions.txt" available on Moodle using a PCA.
